# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Raw data provided
months = np.arange(1,145)
production_data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391, 2150, 2340, 3129,
    2277, 2964, 2997, 2747, 2862, 3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531, 3477, 3376,
    4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422, 4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789,
    4544, 4975, 5211, 4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 6365, 6266, 6345, 6118,
    6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368,
    8933, 8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318, 10393, 10986,
    10635, 10731, 11749, 11849, 12123, 12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162, 13644,
    13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893, 16388, 16782, 16716, 17033, 16896, 17689
]

A = np.vstack([months, np.ones(len(months))]).T
beta, log_alpha = np.linalg.lstsq(A, np.log(production_data), rcond = None)[0]
alpha = np.exp(log_alpha)

def exponential_growth(x, a, b):
    return a * np.exp(b * x)
function = exponential_growth(months, alpha, beta)

# Plot the actual production data and the trend
plt.plot(months, production_data, 'bo',label='Actual Production' )
plt.plot(months, function,'r', label='Non-linear Trend (Exponential Growth)')
plt.xlabel('Month')
plt.ylabel('Production')
plt.title('Monthly Bag Production and Trend (January 2018 - December 2023)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

# Raw data provided
months = np.arange(1, 145)
production_data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391, 2150, 2340, 3129,
    2277, 2964, 2997, 2747, 2862, 3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531, 3477, 3376,
    4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422, 4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789,
    4544, 4975, 5211, 4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 6365, 6266, 6345, 6118,
    6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368,
    8933, 8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318, 10393, 10986,
    10635, 10731, 11749, 11849, 12123, 12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162, 13644,
    13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893, 16388, 16782, 16716, 17033, 16896, 17689
]

# Fit the exponential growth model
A = np.vstack([months, np.ones(len(months))]).T
beta, log_alpha = np.linalg.lstsq(A, np.log(production_data), rcond=None)[0]
alpha = np.exp(log_alpha)

def taylor_approximation(t, alpha, beta):
    # Use the first three terms of the Taylor series expansion for e^(beta * t)
    return alpha * (1 + beta * t + (beta * t)**2 / 2 + (beta * t)**3 / 6)

# Calculate the Taylor series approximation values
taylor_values = taylor_approximation(months, alpha, beta)

# Print the month number and corresponding approximated production value
print("Month\tApproximate Production")
for month, value in zip(months, taylor_values):
    print(f"{month}\t{value:.2f}")
# Out:
# Month	Approximate Production
# 1	1966.96
# 2	1997.36
# 3	2028.24
# 4	2059.59
# 5	2091.43
# 6	2123.76
# 7	2156.58
# 8	2189.91
# 9	2223.75
# 10	2258.11
# 11	2293.00
# 12	2328.42
# 13	2364.38
# 14	2400.88
# 15	2437.94
# 16	2475.56
# 17	2513.75
# 18	2552.51
# 19	2591.86
# 20	2631.79
# 21	2672.32
# 22	2713.45
# 23	2755.19
# 24	2797.55
# 25	2840.53
# 26	2884.14
# 27	2928.39
# 28	2973.29
# 29	3018.83
# 30	3065.04
# 31	3111.91
# 32	3159.45
# 33	3207.67
# 34	3256.58
# 35	3306.18
# 36	3356.48
# 37	3407.49
# 38	3459.22
# 39	3511.67
# 40	3564.84
# 41	3618.75
# 42	3673.40
# 43	3728.81
# 44	3784.97
# 45	3841.89
# 46	3899.58
# 47	3958.05
# 48	4017.31
# 49	4077.35
# 50	4138.20
# 51	4199.85
# 52	4262.31
# 53	4325.59
# 54	4389.70
# 55	4454.64
# 56	4520.43
# 57	4587.06
# 58	4654.54
# 59	4722.89
# 60	4792.10
# 61	4862.19
# 62	4933.16
# 63	5005.02
# 64	5077.78
# 65	5151.44
# 66	5226.01
# 67	5301.50
# 68	5377.92
# 69	5455.26
# 70	5533.54
# 71	5612.77
# 72	5692.95
# 73	5774.09
# 74	5856.20
# 75	5939.28
# ...

# %%
import numpy as np
from scipy.optimize import fsolve

# Raw data provided
months = np.arange(1, 145)
production_data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391, 2150, 2340, 3129,
    2277, 2964, 2997, 2747, 2862, 3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531, 3477, 3376,
    4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422, 4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789,
    4544, 4975, 5211, 4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 6365, 6266, 6345, 6118,
    6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368,
    8933, 8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318, 10393, 10986,
    10635, 10731, 11749, 11849, 12123, 12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162, 13644,
    13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893, 16388, 16782, 16716, 17033, 16896, 17689
]

# Fit the exponential growth model
A = np.vstack([months, np.ones(len(months))]).T
beta, log_alpha = np.linalg.lstsq(A, np.log(production_data), rcond=None)[0]
alpha = np.exp(log_alpha)

# Function representing the production model minus the warehouse capacity
def production_minus_capacity(t, alpha, beta, capacity):
    return alpha * np.exp(beta * t) - capacity

# Solve for the month when production exceeds 25000 bags
capacity = 25000
initial_guess = 100  # Start the search for the root around 100 months
solution = fsolve(production_minus_capacity, initial_guess, args=(alpha, beta, capacity))

# Determine when to start building the new warehouse
exceed_month = solution[0]
start_building_month = exceed_month - 13

print(f"Production exceeds {capacity} bags in month: {exceed_month:.2f}")
print(f"EGIER needs to start building the new warehouse in month: {start_building_month:.2f}")
# Out:
# Production exceeds 25000 bags in month: 166.73
# EGIER needs to start building the new warehouse in month: 153.73
